# %% [markdown]
# # Random Graphs: Second Team Homework

# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

#import itertools
import logging
logging.captureWarnings(True) # Logging warnings in order to suppress them

# %% [markdown]
# ## Exercise 1
# Write a function that computes the second smallest eigenvalue λ_1 of the unweighted normalized graph Laplacian for a given graph with n vertices.
#
# Then write a script that uses the assigned dateset, and computes the sequence of second smallest eigenvalue λ_1(k) of the cumulative graph Edges(1 : k, 1 : 2), where 1 ≤ k ≤ m denotes the running number of edges.
#
# Specifically, order the edges according to their weights from file \*weight.txt, starting with the largest weight first and then continue in a monotonic decreasing order.

# %%
# Load data
file_location = "../kn57Nodes1to57_adj20.txt" 
adj_matrix = np.genfromtxt(file_location, delimiter=' ', skip_header = 1)
graph = nx.Graph(adj_matrix)

# %%
nx.draw(graph)

# %%
# Testing the subgraph generation
graph_from_first_n_edges = lambda G, n: nx.from_edgelist(list(graph.edges)[:n])
subgraph = graph_from_first_n_edges(graph, 10)
nx.draw(subgraph)

# %%
def second_smallest_eigenvalue_of_normalized_laplacian(G):
    subgraph_laplacian = nx.normalized_laplacian_matrix(G).todense()
    eigenvalues = np.linalg.eigvals(subgraph_laplacian)
    return sorted(eigenvalues)[1]
    
second_smallest_eigenvalue_of_normalized_laplacian(subgraph)
# Out:
# 0.9999999999999998

# %%
# Compute the second smallest eigenvalue of the cumulative graph Edges(1 : k, 1 : 2), 
# where 1 ≤ k ≤ m is the running number of edges
second_smallest_eigenvals = \
    [second_smallest_eigenvalue_of_normalized_laplacian(graph_from_first_n_edges(graph, n)) \
     for n in range(1,graph.number_of_edges()+1)]

# %%
for i in range(0,len(second_smallest_eigenvals),20): 
    print(f"graph from first {i} edges:\t lambda_1 of normalized laplacian is {second_smallest_eigenvals[i]}")
# Out:
# graph from first 0 edges:	 lambda_1 of normalized laplacian is 2.0
# graph from first 20 edges:	 lambda_1 of normalized laplacian is 0.9999999999999987
# graph from first 40 edges:	 lambda_1 of normalized laplacian is (0.4180151044256631+0j)
# graph from first 60 edges:	 lambda_1 of normalized laplacian is (0.46487851362615273+0j)
# graph from first 80 edges:	 lambda_1 of normalized laplacian is 0.5280782373894608
# graph from first 100 edges:	 lambda_1 of normalized laplacian is (0.6381998417134956+0j)
# graph from first 120 edges:	 lambda_1 of normalized laplacian is 0.6133624043658957
# graph from first 140 edges:	 lambda_1 of normalized laplacian is 0.2154508200963456
# graph from first 160 edges:	 lambda_1 of normalized laplacian is 0.2843486591962228
# graph from first 180 edges:	 lambda_1 of normalized laplacian is 0.3008645798524618
# graph from first 200 edges:	 lambda_1 of normalized laplacian is (0.2634888511998812+0j)
# graph from first 220 edges:	 lambda_1 of normalized laplacian is 0.27962813911084117
# graph from first 240 edges:	 lambda_1 of normalized laplacian is 0.3177453398176074
# graph from first 260 edges:	 lambda_1 of normalized laplacian is 0.33134256238339727
# graph from first 280 edges:	 lambda_1 of normalized laplacian is 0.3473073750380717
# graph from first 300 edges:	 lambda_1 of normalized laplacian is 0.3581784953908678
# graph from first 320 edges:	 lambda_1 of normalized laplacian is 0.3649129667195636
# graph from first 340 edges:	 lambda_1 of normalized laplacian is 0.38896922766687475
# graph from first 360 edges:	 lambda_1 of normalized laplacian is 0.34873043423438216
# graph from first 380 edges:	 lambda_1 of normalized laplacian is 0.3691405864294288
# graph from first 400 edges:	 lambda_1 of normalized laplacian is 0.37722249542158104
# graph from first 420 edges:	 lambda_1 of normalized laplacian is 0.38073013060492744
# graph from first 440 edges:	 lambda_1 of normalized laplacian is 0.385804456325316
# graph from first 460 edges:	 lambda_1 of normalized laplacian is 0.39385566377598574
# graph from first 480 edges:	 lambda_1 of normalized laplacian is 0.395720866764985
# graph from first 500 edges:	 lambda_1 of normalized laplacian is 0.2644014768907723
# graph from first 520 edges:	 lambda_1 of normalized laplacian is 0.26479510028395997
# graph from first 540 edges:	 lambda_1 of normalized laplacian is 0.26600902274931393
# graph from first 560 edges:	 lambda_1 of normalized laplacian is 0.2664673892000009
# graph from first 580 edges:	 lambda_1 of normalized laplacian is 0.27249480263506254
# graph from first 600 edges:	 lambda_1 of normalized laplacian is 0.2766818902257155
# graph from first 620 edges:	 lambda_1 of normalized laplacian is 0.27725788649831123
# graph from first 640 edges:	 lambda_1 of normalized laplacian is 0.20495929415507208
# graph from first 660 edges:	 lambda_1 of normalized laplacian is 0.2050385371208464
# graph from first 680 edges:	 lambda_1 of normalized laplacian is 0.20613175749652063
# graph from first 700 edges:	 lambda_1 of normalized laplacian is 0.20695742033818953
# graph from first 720 edges:	 lambda_1 of normalized laplacian is 0.20701111447648482
# graph from first 740 edges:	 lambda_1 of normalized laplacian is 0.20798889561735956
# graph from first 760 edges:	 lambda_1 of normalized laplacian is 0.19197736171486396
# graph from first 780 edges:	 lambda_1 of normalized laplacian is 0.1571063651466725
# graph from first 800 edges:	 lambda_1 of normalized laplacian is 0.13819509634544583

# %%
plt.style.use('ggplot')
plt.figure(figsize=(20,15))
plt.plot(second_smallest_eigenvals)
plt.xlabel("Number of edges in graph")
plt.ylabel("Second smallest eigenvalue of normalized Laplacian")
pass # To hide output of last run command

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### Question 1

# %%
weight_matrix = np.array(\
# 1  2  3  4  5  6
[[0, 4, 1, 0, 0, 3], # 1
 [4, 0, 2, 0, 0, 1], # 2
 [1, 2, 0, 2, 1, 0], # 3
 [0, 0, 2, 0, 4, 1], # 4
 [0, 0, 1, 4, 0, 2], # 5
 [3, 1, 0, 1, 2, 0]  # 6
])
print(weight_matrix)
# Check if matrix is symmetric, to validate  
# that weights are entered correctly
print(f"Matrix symmetric? {np.allclose(weight_matrix, weight_matrix.T)}")
# Out:
# [[0 4 1 0 0 3]
#  [4 0 2 0 0 1]
#  [1 2 0 2 1 0]
#  [0 0 2 0 4 1]
#  [0 0 1 4 0 2]
#  [3 1 0 1 2 0]]
# Matrix symmetric? True

# %%
G = nx.Graph(weight_matrix)
laplacian = nx.laplacian_matrix(G).todense()
normalized_laplacian = nx.normalized_laplacian_matrix(G).todense()
eigenvalues, eigenvectors = np.linalg.eig(normalized_laplacian)

print("Laplacian matrix:", laplacian, "",
      "Normalized Laplacian matrix:", normalized_laplacian, "", 
      "Eigenvalues:", eigenvalues, "",
      "Eigenvectors:", eigenvectors,
      sep="\n")
# Out:
# Laplacian matrix:
# [[ 8 -4 -1  0  0 -3]
#  [-4  7 -2  0  0 -1]
#  [-1 -2  6 -2 -1  0]
#  [ 0  0 -2  7 -4 -1]
#  [ 0  0 -1 -4  7 -2]
#  [-3 -1  0 -1 -2  7]]
#
# Normalized Laplacian matrix:
# [[ 1.         -0.53452248 -0.14433757  0.          0.         -0.40089186]
#  [-0.53452248  1.         -0.3086067   0.          0.         -0.14285714]
#  [-0.14433757 -0.3086067   1.         -0.3086067  -0.15430335  0.        ]
#  [ 0.          0.         -0.3086067   1.         -0.57142857 -0.14285714]
#  [ 0.          0.         -0.15430335 -0.57142857  1.         -0.28571429]
#  [-0.40089186 -0.14285714  0.         -0.14285714 -0.28571429  1.        ]]
#
# Eigenvalues:
# [0.         0.44155271 0.90153939 1.65607672 1.56455746 1.43627373]
#
# Eigenvectors:
# [[ 0.43643578  0.49216179 -0.16377551 -0.52035065 -0.5077644  -0.10903523]
#  [ 0.40824829  0.46680562  0.27052617  0.43313913  0.37207392 -0.46496552]
#  [ 0.37796447 -0.0443707   0.66668519 -0.1756971   0.11694114  0.60511177]
#  [ 0.40824829 -0.52354613  0.10926966  0.4190177  -0.58265988 -0.17951199]
#  [ 0.40824829 -0.5074785  -0.18098343 -0.47053017  0.46828355 -0.3199309 ]
#  [ 0.40824829  0.07915521 -0.64095957  0.3373155   0.17685892  0.52074734]]

# %% [markdown]
# ### Question 2

# %%
from itertools import chain, combinations

def subsets(nodes):
    """Given list of nodes, generate all subsets of nodes which have length between 1 and len(nodes)/2."""
    return list(chain.from_iterable(combinations(nodes, r) for r in range(1,(len(nodes)//2)+1)))
def cut_complement(G, nodes): return G.nodes - nodes
def cheeger_criterion(G, A): return len(list(nx.edge_boundary(G,A))) / min(len(A), len(cut_complement(G,A)))

def cheeger_number_partition(G):
    G_subsets = subsets(G.nodes)
    cheeger_number = min([cheeger_criterion(G,A) for A in G_subsets])
    cheeger_partition = G_subsets[cheeger_ratios.index(cheeger_number)]
    return cheeger_number, cheeger_partition

cheeger_number, cheeger_partition = cheeger_number_partition(G)
print("Cheeger number:", cheeger_number)
print("Partition associated with Cheeger number:", cheeger_partition)
# Out:
# Cheeger number: 1.3333333333333333
# Partition associated with Cheeger number: (0, 1, 2)

# %% [markdown]
# ### Question 3

# %%
initialization = [v for v, g in zip(G.nodes,eigenvectors[1]) if g >= 0]
print("Initialization:", initialization)
initialization_cheeger = cheeger_criterion(G, initialization)
print("Associated Cheeger criterion value:", initialization_cheeger, 
     "\nversus actual value of", cheeger_number)
# Out:
# Initialization: [0, 1, 2, 3, 4]
# Associated Cheeger criterion value: 4.0
# versus actual value of 1.3333333333333333
